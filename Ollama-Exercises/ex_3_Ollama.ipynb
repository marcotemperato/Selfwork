# %% [markdown]
# # Esercizio 3
#
# **Traccia:** Crea un prompt che riassuma un articolo di notizie in un singolo paragrafo di al massimo 255 caratteri.
#
# **Obiettivo:** Prendere un testo lungo e condensarlo nei punti essenziali.

# %%
import ollama

input_text = input("Inserisci testo: ")

response = ollama.chat(
    model="llama3",
    messages=[{"role": "system", "content": "Riassumi il testo in un singolo paragrafo con al massimo 255 caratteri."},
              {"role": "user", "content": input_text}]
)
print(response['message']['content'])
# Out:
# Gioia del Colle è un borgo incastonato tra le Murge e la costa barese, dominato dal Castello Normanno-Svevo. È famoso per la produzione di mozzarella D.O.P. e vino Primitivo, espressione autentica della campagna pugliese.
